# %%
with open("texto_utf8.txt", "r", encoding="utf-8") as jorge:
    print(jorge.readlines()[-1])
# Out:
# A acentuação das palavras como macarrão, vírus, silêncio, ações e ginásio podem ser exibidas erradas se o encoding de texto não for usado certo.

# %%
frase = "era uma vez"
frase = frase[0:6]
print(frase)
# Out:
# era um

# %%
import pandas as pd # manipulação de tabelas

# %%
# csv --> comma separated values
df = pd.read_csv("gaf_esp.csv", sep=";")
df.sample()
# Out:
#       Espécie  Comprimento do Abdômen  Comprimento das Antenas
# 32  Gafanhoto                     1.5                      6.0

# %%
import seaborn as sns

sns.pairplot(df)
